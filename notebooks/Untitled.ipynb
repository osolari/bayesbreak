# %%
# %load_ext autoreload
# %autoreload 2

# %%
from bayesbreak.constants import REPO_DIR

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 bayesbreak.utils
#
# AttributeError: module 'bayesbreak' has no attribute 'utils'
